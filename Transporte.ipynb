# %%
# !pip install folium geopy rtree matplotlib mapclassify geojson
# !pip install geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in /home/malobato/.local/lib/python3.9/site-packages (0.12.1.post1)
# Requirement already satisfied: geopy in /home/malobato/.local/lib/python3.9/site-packages (2.2.0)
# Requirement already satisfied: rtree in /home/malobato/.local/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: matplotlib in /home/malobato/.local/lib/python3.9/site-packages (3.5.2)
# Requirement already satisfied: mapclassify in /home/malobato/.local/lib/python3.9/site-packages (2.4.3)
# Collecting geojson
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy in /home/malobato/.local/lib/python3.9/site-packages (from folium) (1.22.4)
# Requirement already satisfied: branca>=0.3.0 in /home/malobato/.local/lib/python3.9/site-packages (from folium) (0.5.0)
# Requirement already satisfied: requests in /home/malobato/.local/lib/python3.9/site-packages (from folium) (2.27.1)
# Requirement already satisfied: jinja2>=2.9 in /home/malobato/.local/lib/python3.9/site-packages (from folium) (3.1.2)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/malobato/.local/lib/python3.9/site-packages (from geopy) (1.52)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/malobato/.local/lib/python3.9/site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/malobato/.local/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/malobato/.local/lib/python3.9/site-packages (from matplotlib) (9.1.1)
# Requirement already satisfied: packaging>=20.0 in /home/malobato/.local/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages/python_dateutil-2.8.2-py3.9.egg (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/malobato/.local/lib/python3.9/site-packages (from matplotlib) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /home/malobato/.local/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: networkx in /home/malobato/.local/lib/python3.9/site-packages (from mapclassify) (2.8.3)
# Requirement already satisfied: scipy>=1.0 in /home/malobato/.local/lib/python3.9/site-packages (from mapclassify) (1.8.1)
# Requirement already satisfied: scikit-learn in /home/malobato/.local/lib/python3.9/site-packages (from mapclassify) (1.1.1)
# Requirement already satisfied: pandas>=1.0 in /home/malobato/.local/lib/python3.9/site-packages (from mapclassify) (1.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/malobato/.local/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: pytz>=2020.1 in /home/malobato/.local/lib/python3.9/site-packages (from pandas>=1.0->mapclassify) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages/certifi-2021.10.8-py3.9.egg (from requests->folium) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages/urllib3-1.26.7-py3.9.egg (from requests->folium) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages/charset_normalizer-2.0.9-py3.9.egg (from requests->folium) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages/idna-3.3-py3.9.egg (from requests->folium) (3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/malobato/.local/lib/python3.9/site-packages (from scikit-learn->mapclassify) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/malobato/.local/lib/python3.9/site-packages (from scikit-learn->mapclassify) (1.1.0)
# Installing collected packages: geojson
# Successfully installed geojson-2.5.0
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopandas in /home/malobato/.local/lib/python3.9/site-packages (0.10.2)
# Requirement already satisfied: shapely>=1.6 in /home/malobato/.local/lib/python3.9/site-packages (from geopandas) (1.8.2)
# Requirement already satisfied: pyproj>=2.2.0 in /home/malobato/.local/lib/python3.9/site-packages (from geopandas) (3.3.1)
# Requirement already satisfied: fiona>=1.8 in /home/malobato/.local/lib/python3.9/site-packages (from geopandas) (1.8.21)
# Requirement already satisfied: pandas>=0.25.0 in /home/malobato/.local/lib/python3.9/site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: six>=1.7 in /usr/lib/python3/dist-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from fiona>=1.8->geopandas) (52.0.0)
# Requirement already satisfied: click-plugins>=1.0 in /home/malobato/.local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: munch in /home/malobato/.local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /home/malobato/.local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages/certifi-2021.10.8-py3.9.egg (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: attrs>=17 in /home/malobato/.local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: click>=4.0 in /home/malobato/.local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (8.0.3)
# Requirement already satisfied: pytz>=2020.1 in /home/malobato/.local/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /home/malobato/.local/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages/python_dateutil-2.8.2-py3.9.egg (from pandas>=0.25.0->geopandas) (2.8.2)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import folium
import geopandas as gpd
import pandas as pd
import os
import geojson
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster, Fullscreen, MousePosition
# Out:
# /home/malobato/.local/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
def load_shapefile(name, cols=None, index=None, rename=None):
    path = os.path.abspath(f"./data/{name}.zip")
    df = gpd.read_file(f'zip://{path}')

    if cols:
        df = df[cols]
    if rename:
        df = df.rename(columns=rename)
    if index:
        df = df.set_index(index)
    return df.to_crs(epsg=4326)
    

def add_barrios(m):
    for name, r in barrios.iterrows():
        # Without simplifying the representation of each borough,
        # the map might not be displayed
        sim_geo = gpd.GeoSeries(r['geometry']).simplify(tolerance=0.001)
        geo_j = sim_geo.to_json()
        geo_j = folium.GeoJson(data=geo_j,
                               style_function=lambda x: {'fillColor': 'orange'})
        folium.Popup(f"<b>Barrio:</b> <span style='white-space: nowrap;'>{name}</span>").add_to(geo_j)
        geo_j.add_to(m)
    m



def get_map(withbarrios=True):
    #tiles maps: https://github.com/python-visualization/folium/tree/main/folium/templates/tiles
    # Create a base map
    m = folium.Map(location=[40.422, -3.696], tiles='stamentoner', zoom_start=12)
    m.add_child(Fullscreen())
    m.add_child(MousePosition())
    
    if withbarrios:
        add_barrios(m)
    
    return m

# %%
# Barrios and distritos Dataset
lambda_rename = lambda x:x.upper().replace("Á", "A").replace("É", "E").replace("Í", "I").replace("Ó", "O").replace("Ú", "U")
poblacion_barrios = pd.read_csv("./data/poblacion-barrios.csv").set_index("NOMBRE").to_dict()["Total"]

barrios = load_shapefile("barrios", ["NOMBRE", "geometry"])
distritos = load_shapefile("distritos", ["DISTRI_MAY", "geometry"], rename={"DISTRI_MAY": "NOMBRE"}, index="NOMBRE")

barrios["NOMBRE"] = barrios.apply(lambda x:lambda_rename(x['NOMBRE']), axis=1)
barrios["poblacion"] = barrios.apply(lambda x:int(poblacion_barrios[x['NOMBRE']]), axis=1)

barrios = barrios.set_index("NOMBRE")

# %%
# Load all Datasets
bus_interurbano_estaciones = load_shapefile("bus-interurbano-estaciones", 
                                            cols=["IDPOSTE", "geometry"], 
                                            rename={"IDPOSTE": "NOMBRE"},
                                            index="NOMBRE")
bus_interurbano_estaciones["TYPE"] = "bus-interurbano-estaciones"
bus_interurbano_estaciones["latitude"] = bus_interurbano_estaciones.apply(lambda x: x['geometry'].y, axis=1)
bus_interurbano_estaciones["longitude"] = bus_interurbano_estaciones.apply(lambda x: x['geometry'].x, axis=1)

bus_urbano_madrid_estaciones = load_shapefile("bus-urbano-madrid-estaciones", 
                                              cols=["IDPOSTE", "geometry"], 
                                              rename={"IDPOSTE": "NOMBRE"},
                                              index="NOMBRE")
bus_urbano_madrid_estaciones["TYPE"] = "bus-urbano-madrid-estaciones"
bus_urbano_madrid_estaciones["latitude"] = bus_urbano_madrid_estaciones.apply(lambda x: x['geometry'].y, axis=1)
bus_urbano_madrid_estaciones["longitude"] = bus_urbano_madrid_estaciones.apply(lambda x: x['geometry'].x, axis=1)

bus_urbano_no_madrid_estaciones = load_shapefile("bus-urbano-no-madrid-estaciones", 
                                                 cols=["IDPOSTE", "geometry"], 
                                                 rename={"IDPOSTE": "NOMBRE"},
                                                 index="NOMBRE")
bus_urbano_no_madrid_estaciones["TYPE"] = "bus-urbano-no-madrid-estaciones"
bus_urbano_no_madrid_estaciones["latitude"] = bus_urbano_no_madrid_estaciones.apply(lambda x: x['geometry'].y, axis=1)
bus_urbano_no_madrid_estaciones["longitude"] = bus_urbano_no_madrid_estaciones.apply(lambda x: x['geometry'].x, axis=1)
bus_urbano_estaciones = pd.concat([bus_urbano_madrid_estaciones, bus_urbano_no_madrid_estaciones])

cercanias_estaciones = load_shapefile("cercanias-estaciones", 
                                      cols=["DENOMINACI", "geometry"], 
                                      rename={"DENOMINACI": "NOMBRE"}, 
                                      index="NOMBRE")
cercanias_estaciones["TYPE"] = "cercanias-estaciones"
cercanias_estaciones["latitude"] = cercanias_estaciones.apply(lambda x: x['geometry'].y, axis=1)
cercanias_estaciones["longitude"] = cercanias_estaciones.apply(lambda x: x['geometry'].x, axis=1)

metro_estaciones = load_shapefile("metro-estaciones", 
                                  cols=["DENOMINACI", "geometry"], 
                                  rename={"DENOMINACI": "NOMBRE"}, 
                                  index="NOMBRE")
metro_estaciones["TYPE"] = "metro-estaciones"
metro_estaciones["latitude"] = metro_estaciones.apply(lambda x: x['geometry'].y, axis=1)
metro_estaciones["longitude"] = metro_estaciones.apply(lambda x: x['geometry'].x, axis=1)

metro_ligero_estaciones = load_shapefile("metro-ligero-estaciones", 
                                         cols=["DENOMINACI", "geometry"], 
                                         rename={"DENOMINACI": "NOMBRE"}, 
                                         index="NOMBRE")
metro_ligero_estaciones["TYPE"] = "metro-ligero-estaciones"
metro_ligero_estaciones["latitude"] = metro_ligero_estaciones.apply(lambda x: x['geometry'].y, axis=1)
metro_ligero_estaciones["longitude"] = metro_ligero_estaciones.apply(lambda x: x['geometry'].x, axis=1)

#bus_interurbano_estaciones, bus_urbano_estaciones
#cercanias_estaciones, metro_estaciones, metro_ligero_estaciones
#pd.concat([A, B])

# %%
#bus_interurbano_estaciones, bus_urbano_estaciones
#cercanias_estaciones, metro_estaciones, metro_ligero_estaciones
#pd.concat([A, B])

df = bus_urbano_estaciones

# Show bicimad stations as heatmap
m = get_map()
HeatMap(data=df[['latitude', 'longitude']], radius=20).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7ed6c7c5cb047030ad0b05d5402badb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@master/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7ed6c7c5cb047030ad0b05d5402badb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c7ed6c7c5cb047030ad0b05d5402badb = L.map(
#                 &quot;map_c7ed6c7c5cb047030ad0b05d5402badb&quot;,
#                 {
#                     center: [40.422, -3.696],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4da2e335fa6c22bccd46ad378019c03 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c7ed6c7c5cb047030ad0b05d5402badb);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_c7ed6c7c5cb047030ad0b05d5402badb);
#
#
#             var mouse_position_67239e001a4e590fe366385c2c20ad40 = new L.Control.MousePosition(
#                 {&quot;emptyString&quot;: &quot;Unavailable&quot;, &quot;lngFirst&quot;: false, &quot;numDigits&quot;: 5, &quot;position&quot;: &quot;bottomright&quot;, &quot;prefix&quot;: &quot;&quot;, &quot;separator&quot;: &quot; : &quot;}
#             );
#             mouse_position_67239e001a4e590fe366385c2c20ad40.options[&quot;latFormatter&quot;] =
#                 undefined;
#             mouse_position_67239e001a4e590fe366385c2c20ad40.options[&quot;lngFormatter&quot;] =
#                 undefined;
#             map_c7ed6c7c5cb047030ad0b05d5402badb.addControl(mouse_position_67239e001a4e590fe366385c2c20ad40);
#
#
#         function geo_json_43feba803366acb0237b9cf88e9b6e56_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;};
#             }
#         }
#
#         function geo_json_43feba803366acb0237b9cf88e9b6e56_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_43feba803366acb0237b9cf88e9b6e56 = L.geoJson(null, {
#                 onEachFeature: geo_json_43feba803366acb0237b9cf88e9b6e56_onEachFeature,
#
#                 style: geo_json_43feba803366acb0237b9cf88e9b6e56_styler,
#         });
#
#         function geo_json_43feba803366acb0237b9cf88e9b6e56_add (data) {
#             geo_json_43feba803366acb0237b9cf88e9b6e56
#                 .addData(data)
#                 .addTo(map_c7ed6c7c5cb047030ad0b05d5402badb);
#         }
#             geo_json_43feba803366acb0237b9cf88e9b6e56_add({&quot;bbox&quot;: [-3.6929679617869082, 40.332732977174885, -3.6837909114265264, 40.350214958848454], &quot;features&quot;: [{&quot;bbox&quot;: [-3.6929679617869082, 40.332732977174885, -3.6837909114265264, 40.350214958848454], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-3.6837909114265264, 40.350214958848454], [-3.6845275702400073, 40.337408628862306], [-3.687715128823964, 40.33425033063338], [-3.6925503128226858, 40.332732977174885], [-3.6929679617869082, 40.34584760405907], [-3.6866567409012396, 40.3476082994256], [-3.6837909114265264, 40.350214958848454]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_70d3526b0d782f01fbd215f09af06f8c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_564fd972bd9eea68e181970c18be86a4 = $(`&lt;div id=&quot;html_564fd972bd9eea68e181970c18be86a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Barrio:&lt;/b&gt; &lt;span style=&#x27;white-space: nowrap;&#x27;&gt;SAN CRISTOBAL&lt;/span&gt;&lt;/div&gt;`)[0];
#             popup_70d3526b0d782f01fbd215f09af06f8c.setContent(html_564fd972bd9eea68e181970c18be86a4);
#
#
#         geo_json_43feba80

# %%
#bus_interurbano_estaciones, bus_urbano_estaciones
#cercanias_estaciones, metro_estaciones, metro_ligero_estaciones
#pd.concat([bus_interurbano_estaciones, bus_urbano_estaciones, cercanias_estaciones, metro_estaciones, metro_ligero_estaciones])

df = pd.concat([bus_interurbano_estaciones, bus_urbano_estaciones, cercanias_estaciones, metro_estaciones, metro_ligero_estaciones])

#calculate dictionaries
estaciones_barrios = gpd.sjoin(barrios, df).reset_index()
estaciones_barrios = estaciones_barrios[["NOMBRE"]].groupby(['NOMBRE'])['NOMBRE'].count().squeeze().to_dict()
estaciones_data = {key: {
    "poblacion": poblacion_barrios[key],
    "estaciones": val,
    "estaciones/1000": float(val)*1000.0/float(poblacion_barrios[key])
} for key,val in estaciones_barrios.items()}


estaciones_cp = {key: val["estaciones/1000"] for key,val in estaciones_data.items()}

# Create a base map
m = get_map(withbarrios=False)


# Add a choropleth map to the base map
cp = Choropleth(geo_data=barrios.__geo_interface__,
           data=estaciones_cp, 
           key_on="feature.id", 
           fill_color="OrRd", 
           legend_name='Bicimad Station docks per district',
           nan_fill_color = "LightGrey"
          ).add_to(m)

# add popup
for s in cp.geojson.data['features']:
    s['properties']['NOMBRE'] = s['id']
    s['properties']['estaciones'] = estaciones_data.get(s['id'], {}).get("estaciones", 0)
    s['properties']['estaciones/1000'] = round(estaciones_data.get(s['id'], {}).get("estaciones/1000", 0), 2)
    
folium.GeoJsonTooltip(['NOMBRE', 'poblacion', 'estaciones', 'estaciones/1000']).add_to(cp.geojson)
folium.LayerControl().add_to(m)

# Display the map
cp.geojson

# %%
import branca.colormap as cm
import statistics
vmax,vmedian = round(max(estaciones_cp.values()) * 100), round(statistics.median(estaciones_cp.values()) * 100)
colormap = cm.LinearColormap(colors=['orange','red','darkred'], index=[0,vmedian,vmax], vmin=0, vmax=vmax).to_step(n=10)

#plotting
m = get_map(withbarrios=False)

folium.GeoJson(
    cp.geojson.data,
    style_function=lambda feature: {
        'fillColor': 'red' if feature['properties']['estaciones/1000'] == 0 else colormap(feature['properties']['estaciones/1000']*100),
        'color': 'black',
        'weight': 2,
        'dashArray': '5, 5'
    }
).add_to(m)
colormap.add_to(m)



m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7be7511a229214dd895383e014dbad7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7be7511a229214dd895383e014dbad7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7be7511a229214dd895383e014dbad7e = L.map(
#                 &quot;map_7be7511a229214dd895383e014dbad7e&quot;,
#                 {
#                     center: [40.422, -3.696],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d482221785edb4a460ce957ad5a09853 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7be7511a229214dd895383e014dbad7e);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_7be7511a229214dd895383e014dbad7e);
#
#
#             var mouse_position_2704872093aa394b4fd79ea16c899279 = new L.Control.MousePosition(
#                 {&quot;emptyString&quot;: &quot;Unavailable&quot;, &quot;lngFirst&quot;: false, &quot;numDigits&quot;: 5, &quot;position&quot;: &quot;bottomright&quot;, &quot;prefix&quot;: &quot;&quot;, &quot;separator&quot;: &quot; : &quot;}
#             );
#             mouse_position_2704872093aa394b4fd79ea16c899279.options[&quot;latFormatter&quot;] =
#                 undefined;
#             mouse_position_2704872093aa394b4fd79ea16c899279.options[&quot;lngFormatter&quot;] =
#                 undefined;
#             map_7be7511a229214dd895383e014dbad7e.addControl(mouse_position_2704872093aa394b4fd79ea16c899279);
#
#
#         function geo_json_5c3960c6ef3b6f753e8e8b0809f587b3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;CUATRO VIENTOS&quot;: case &quot;ORCASUR&quot;: case &quot;PAVONES&quot;: case &quot;SOL&quot;: case &quot;LOS JERONIMOS&quot;: case &quot;EL SALVADOR&quot;: case &quot;EL VISO&quot;: case &quot;PALOMAS&quot;: case &quot;ARAVACA&quot;: case &quot;ATALAYA&quot;: case &quot;ALMENARA&quot;: case &quot;CASTILLA&quot;: case &quot;FUENTELARREINA&quot;: case &quot;EL GOLOSO&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#f90000ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;ATOCHA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#b40000ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;CASA DE CAMPO&quot;: case &quot;CORRALEJOS&quot;: case &quot;VALDEMARIN&quot;: case &quot;EL PARDO&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#eb0000ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;CIUDAD UNIVERSITARIA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#de0000ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;EL PLANTIO&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#d00000ff&quot;, &quot;weight&quot;: 2};
#                 case &quot;AEROPUERTO&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#8b0000ff&quot;, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#ffa500ff&quot;, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_5c3960c6ef3b6f753e8e8b0809f587b3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5c
